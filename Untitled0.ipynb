# %% [markdown]
# <a href="https://colab.research.google.com/github/kanokwantho/DW_lab_6730202435/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## นางสาวกนกวรรณ ทองเทพ

# %%
print('673020243-5')
# Out:
# 673020243-5
